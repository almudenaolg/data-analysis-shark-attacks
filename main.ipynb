# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from cleaning import*
url = 'https://www.sharkattackfile.net/spreadsheets/GSAF5.xls'
df = pd.read_excel(url)

# %% [markdown]
# ### Step 1. Cleaning the dataframe
# Apply the data cleaning functions and save the result in the dataframe variable.
# First we delete the columns that are not interesting for our analysis. We then apply a function that standardizes the column names and deletes duplicates and null values. We also standardized the values ​​of the 'date' and 'activity' columns. Finally, we apply a filter with the date from which we are interested in the data.

# %%
df = delete_columns(df)
df= clean_data(df)
df['date'] = df['date'].apply(remove_prefix)
df['date'] = df['date'].apply(fix_format_date)
df['activity'] = df['activity'].apply(standarize_activities)
df = filter_date(df)

df
# Out:
#            date       country                  state  activity
# 8    2024-09-01     AUSTRALIA        South Australia   Surfing
# 9    2024-05-01  SOUTH AFRICA  Eastern Cape Province   Fishing
# 74   2023-07-06       BAHAMAS               Freeport    Diving
# 84   2023-11-05           USA                Florida   Sitting
# 85   2023-11-05           USA                 Hawaii   Fishing
# ...         ...           ...                    ...       ...
# 2682 2000-09-03     AUSTRALIA        New South Wales    Rowing
# 2684 2000-02-03     AUSTRALIA        New South Wales  Swimming
# 2689 2000-03-02   NEW ZEALAND           South Island   Surfing
# 2690 2000-01-02     AUSTRALIA        South Australia   Surfing
# 2692 2000-05-01      THAILAND     Phang nga Province    Diving
#
# [904 rows x 4 columns]

# %% [markdown]
# ### Step 2. Basic statistics
# Since we are dealing with columns with categorical values, we calculate their mode.

# %%
get_mode_of_attacks(df)
# Out:
# {'most_attacked_country': 'USA',
#  'most_attacked_state': 'Florida',
#  'most_common_activity': 'Surfing'}

# %% [markdown]
# ### Step 3. Combining data
# To better understand the patterns that occur in shark attacks, we combine the variables we have to extract the most frequent ones.

# %%
top_country_state_activity(df, 10)
# Out:
# Top 10 combinaciones país-estado-actividad más frecuentes:
# country       state                  activity
# USA           Florida                Surfing     89
#                                      Swimming    71
# AUSTRALIA     New South Wales        Surfing     49
# USA           California             Surfing     27
#               Hawaii                 Surfing     26
#               Florida                Fishing     15
#               North Carolina         Swimming    14
# AUSTRALIA     Western Australia      Surfing     12
# SOUTH AFRICA  Eastern Cape Province  Surfing     11
# BRAZIL        Pernambuco             Swimming    10
# dtype: int64

# %% [markdown]
# ### Step 4. Data visualization

# %% [markdown]
# Show in a bar graph the top 10 countries with the most shark attacks, to better understand their geographical distribution.

# %%
plot_top_countries_attacks(df, top_n=10)

# %% [markdown]
# See in a bar graph what are the most common activities when a shark attack occurs.

# %%
plot_top_activties(df)

# %% [markdown]
# Show in a graph the distribution of attacks by month globally, to see if there is any general trend.

# %%
plot_attacks_per_month(df)

# %% [markdown]
# Show in a bar graph the states where the most attacks occur, to better understand the dangerous areas.

# %%
plot_top_states(df)

# %% [markdown]
# Show in a graph the attacks that occurred in the top 5 states and in the 5 most frequent activities.

# %%
plot_top_states_activities(df)

# %% [markdown]
# See in a graph the months where the attacks are concentrated in the most affected country, to know their temporality

# %%
plot_attacks_per_month_USA (df)
